# %% [markdown]
# ### Importing the needed Libraries

# %%
import pandas as pd
import numpy as np

# %%
#loading the diabetes prediction dataset to a pandas dataframe
diabetes_dataset = pd.read_csv('diabetes_prediction_dataset.csv')

#printing the first 100 rows of dataset
diabetes_dataset.head(5)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
diabetes_dataset.shape
# Out:
# (100000, 9)

# %%
diabetes_dataset.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
diabetes_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
# getting the statisyical measure of thr data
diabetes_dataset.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
diabetes_dataset.describe().T
# Out:
#                         count        mean        std    min     25%     50%  \
# age                  100000.0   41.885856  22.516840   0.08   24.00   43.00
# hypertension         100000.0    0.074850   0.263150   0.00    0.00    0.00
# heart_disease        100000.0    0.039420   0.194593   0.00    0.00    0.00
# bmi                  100000.0   27.320767   6.636783  10.01   23.63   27.32
# HbA1c_level          100000.0    5.527507   1.070672   3.50    4.80    5.80
# blood_glucose_level  100000.0  138.058060  40.708136  80.00  100.00  140.00
# diabetes             100000.0    0.085000   0.278883   0.00    0.00    0.00
#
#                         75%     max
# age                   60.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.58   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00
# diabetes               0.00    1.00

# %%
diabetes_dataset.isnull().head(10)
# Out:
#    gender    age  hypertension  heart_disease  smoking_history    bmi  \
# 0   False  False         False          False            False  False
# 1   False  False         False          False            False  False
# 2   False  False         False          False            False  False
# 3   False  False         False          False            False  False
# 4   False  False         False          False            False  False
# 5   False  False         False          False            False  False
# 6   False  False         False          False            False  False
# 7   False  False         False          False            False  False
# 8   False  False         False          False            False  False
# 9   False  False         False          False            False  False
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0        False                False     False
# 1        False                False     False
# 2        False                False     False
# ...

# %%
diabetes_dataset.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
diabetes_dataset.dropna()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
diabetes_dataset['diabetes'].value_counts()
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %% [markdown]
# O-------- means Non Diabetic                                        1-------- Means Diabetic

# %%
diabetes_dataset['hypertension'].value_counts()
# if hypentension is 0 that mean non hypten... if 1 it means yes
# Out:
# hypertension
# 0    92515
# 1     7485
# Name: count, dtype: int64

# %%
diabetes_dataset['heart_disease'].value_counts()
# If heart disease is 0 that mean it non whilw 1 means oposite
# Out:
# heart_disease
# 0    96058
# 1     3942
# Name: count, dtype: int64

# %%
diabetes_dataset_copy = diabetes_dataset.copy(deep=True)

# %%
diabetes_dataset_copy[['gender', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level']] = diabetes_dataset_copy[['gender', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level']].replace(0, np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 diabetes_dataset_copy[['gender', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level']] = diabetes_dataset_copy[['gender', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level']].replace(0, np.nan)
#
# NameError: name 'np' is not defined

# %%
print(diabetes_dataset_copy.isnull().sum())
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
p = diabetes_df.hist(figsize=(20, 20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 p = diabetes_df.hist(figsize=(20, 20))
#
# NameError: name 'diabetes_df' is not defined

# %%
mean_values = diabetes_dataset.groupby('diabetes')[numeric_columns].mean()
print(mean_values)
# Out:
#                 age  hypertension  heart_disease        bmi  HbA1c_level  \
# diabetes
# 0         40.115187      0.058984       0.029235  26.887163     5.396761
# 1         60.946588      0.245647       0.149059  31.988382     6.934953
#
#           blood_glucose_level  diabetes
# diabetes
# 0                  132.852470       0.0
# 1                  194.094706       1.0

# %%
# Select numeric columns
numeric_columns = diabetes_dataset.select_dtypes(include=['number']).columns

# Group by 'diabetes' and calculate mean for numeric columns
mean_values = diabetes_dataset.groupby('diabetes')[numeric_columns].mean()
print(mean_values)
# Out:
#                 age  hypertension  heart_disease        bmi  HbA1c_level  \
# diabetes
# 0         40.115187      0.058984       0.029235  26.887163     5.396761
# 1         60.946588      0.245647       0.149059  31.988382     6.934953
#
#           blood_glucose_level  diabetes
# diabetes
# 0                  132.852470       0.0
# 1                  194.094706       1.0

# %%
#seperating the data and labels
X = diabetes_dataset.drop(columns='diabetes', axis=1)
Y = diabetes_dataset['diabetes']

# %%
print(X)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
print(Y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
X_numeric = X.select_dtypes(include=['number'])

# %%
print("Numeric Data:")
# Out:
# Numeric Data:

# %%
print(X_numeric)
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level
# 0                      140
# 1                       80
# 2                      158
# 3                      155
# 4                      155
# ...                    ...
# 99995                   90
# ...

# %%
# One-Hot Encoding Categorical Variables
X_encoded = pd.get_dummies(X)
print("\nEncoded Data:")
print(X_encoded)
# Out:
# Encoded Data:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  gender_Female  gender_Male  gender_Other  \
# 0                      140           True        False         False
# 1                       80           True        False         False
# ...

# %%
scaler = StandardScaler()

# %%
diabetes_dataset_copy = diabetes_dataset.copy(deep=True)
diabetes_dataset_copy[['gender','hypertension', 'heart_disease', 'smoking_history','bmi', 'HbA1c_level', 'blood_glucose_level']] = diabetes_dataset_copy[['gender','hypertension', 'heart_disease', 'smoking_history','bmi', 'HbA1c_level', 'blood_glucose_level']].replace(0, np.NaN)

# Showing the count of NaNs
print(diabetes_dataset_copy.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 2
#       1 diabetes_dataset_copy = diabetes_dataset.copy(deep=True)
# ----> 2 diabetes_dataset_copy[['gender','hypertension', 'heart_disease', 'smoking_history','bmi', 'HbA1c_level', 'blood_glucose_level']] = diabetes_dataset_copy[['gender','hypertension', 'heart_disease', 'smoking_history','bmi', 'HbA1c_level', 'blood_glucose_level']].replace(0, np.NaN)
#       4 # Showing the count of NaNs
#       5 print(diabetes_dataset_copy.isnull().sum())
#
# File c:\Users\Oladi\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\__init__.py:411, in __getattr__(attr)
#     408     raise AttributeError(__former_attrs__[attr])
#     410 if attr in __expired_attributes__:
# --> 411     raise AttributeError(
#     412         f"`np.{attr}` was removed in the NumPy 2.0 release. "
# ...

# %%
scaler.fit(X_numeric)
# Out:
# StandardScaler()
